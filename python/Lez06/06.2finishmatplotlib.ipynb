# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
Data = {'Country': ['USA','Canada','Germany','UK','France'],
        'GDP': [45000,42000,52000,49000,47000]}
  
df = pd.DataFrame(Data)
#df = pd.DataFrame(Data,columns=['Country','GDP_STATE'])

# %%
df.head()
# Out:
#    Country    GDP
# 0      USA  45000
# 1   Canada  42000
# 2  Germany  52000
# 3       UK  49000
# 4   France  47000

# %%
df.plot(x ='Country',y='GDP', figsize=(
    10, 10),
        kind = 'scatter');
#plt.show()

# %%
df.plot(x ='Country',y='GDP', figsize=(10, 10),
        kind = 'line');
#plt.show()

# %%
Data = {'Tasks': [300,500,700]}
df = pd.DataFrame(Data,columns=['Tasks'])

# %%
df.head()
# Out:
#    Tasks
# 0    300
# 1    500
# 2    700

# %%
df = pd.DataFrame(Data,columns=['Tasks'],
                  index = ['Tasks Pending','Tasks Ongoing','Tasks Completed'])
df.head()
# Out:
#                  Tasks
# Tasks Pending      300
# Tasks Ongoing      500
# Tasks Completed    700

# %%
df.plot.pie(y='Tasks',figsize=(10, 10),autopct='%1.1f%%',
            startangle=90);

# %%
### Groupby

# %%
url_superficie = "https://it.wikipedia.org/wiki/Primi_100_comuni_italiani_per_superficie"

# %%
comuni_superficie = pd.read_html(url_superficie,
                                 attrs={"class":"wikitable"},
                                 header=0)

comuni_superficie = comuni_superficie[0]

# %%
comuni_superficie = comuni_superficie.rename(columns={'Superficie (km²)': 'Superficie'})

# %%
comuni_superficie.head()
# Out:
#    Pos.     Comune         Regione Provincia Superficie
# 0     1       Roma           Lazio      Roma   1 287,24
# 1     2    Ravenna  Emilia-Romagna   Ravenna      65381
# 2     3  Cerignola          Puglia    Foggia      59392
# 3     4       Noto         Sicilia  Siracusa      55498
# 4     5    Sassari        Sardegna   Sassari      54703

# %%
#comuni_superficie['Superficie'] = comuni_superficie['Superficie'].str.replace(' ', '').str.replace(',', '.')
comuni_superficie['Superficie'] = comuni_superficie['Superficie'].str.replace(',' , '').str.replace(r'\s', '', regex=True)
comuni_superficie.head()
# Out:
#    Pos.     Comune         Regione Provincia Superficie
# 0     1       Roma           Lazio      Roma     128724
# 1     2    Ravenna  Emilia-Romagna   Ravenna      65381
# 2     3  Cerignola          Puglia    Foggia      59392
# 3     4       Noto         Sicilia  Siracusa      55498
# 4     5    Sassari        Sardegna   Sassari      54703

# %%
#comuni_superficie['Superficie'] = comuni_superficie['Superficie'].astype(float)
#comuni_superficie = pd.to_numeric(comuni_superficie['Superficie Rate']) 
#comuni_superficie['Superficie'] = comuni_superficie['Superficie'].astype(dtype = float, errors = 'coerce')
comuni_superficie['Superficie'] = pd.to_numeric(comuni_superficie['Superficie'], errors = 'coerce')
comuni_superficie # coerce transform not numeric in NaN
# Out:
#     Pos.     Comune         Regione        Provincia  Superficie
# 0      1       Roma           Lazio             Roma      128724
# 1      2    Ravenna  Emilia-Romagna          Ravenna       65381
# 2      3  Cerignola          Puglia           Foggia       59392
# 3      4       Noto         Sicilia         Siracusa       55498
# 4      5    Sassari        Sardegna          Sassari       54703
# ..   ...        ...             ...              ...         ...
# 95    96    Dorgali        Sardegna            Nuoro       22653
# 96    97     Urbino          Marche  Pesaro e Urbino       22649
# 97    98      Cagli          Marche  Pesaro e Urbino       22646
# 98    99     Ostuni          Puglia         Brindisi       22556
# 99   100    Alghero        Sardegna          Sassari       22541
#
# [100 rows x 5 columns]

# %%
comuni_superficie.dropna()
comuni_superficie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pos.        100 non-null    int64
#  1   Comune      100 non-null    object
#  2   Regione     100 non-null    object
#  3   Provincia   100 non-null    object
#  4   Superficie  100 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
comuni_superficie
# Out:
#     Pos.     Comune         Regione        Provincia  Superficie
# 0      1       Roma           Lazio             Roma      128724
# 1      2    Ravenna  Emilia-Romagna          Ravenna       65381
# 2      3  Cerignola          Puglia           Foggia       59392
# 3      4       Noto         Sicilia         Siracusa       55498
# 4      5    Sassari        Sardegna          Sassari       54703
# ..   ...        ...             ...              ...         ...
# 95    96    Dorgali        Sardegna            Nuoro       22653
# 96    97     Urbino          Marche  Pesaro e Urbino       22649
# 97    98      Cagli          Marche  Pesaro e Urbino       22646
# 98    99     Ostuni          Puglia         Brindisi       22556
# 99   100    Alghero        Sardegna          Sassari       22541
#
# [100 rows x 5 columns]

# %%
media_sup_per_regione = comuni_superficie.groupby('Regione', as_index=False)['Superficie'].mean()
#comuni_superficie.groupby('Regione').mean()
media_sup_per_regione = media_sup_per_regione.rename(columns={'Superficie': 'Superficie media comuni'})
media_sup_per_regione
# Out:
#                 Regione  Superficie media comuni
# 0               Abruzzo             47391.000000
# 1            Basilicata             29640.000000
# 2              Calabria             28937.333333
# 3        Emilia-Romagna             31149.700000
# 4                 Lazio             56260.500000
# 5               Liguria             24029.000000
# 6             Lombardia             22700.500000
# 7                Marche             24167.666667
# 8                Puglia             33034.736842
# 9              Sardegna             29028.111111
# 10              Sicilia             32548.631579
# 11              Toscana             29941.928571
# 12  Trentino-Alto Adige             27485.000000
# 13               Umbria             36176.285714
# 14               Veneto             30858.333333

# %%
#reg = comuni_superficie.groupby('Regione')
#reg.aggregate([np.mean, np.std, pd.Series.count])
reg = comuni_superficie.groupby('Regione')['Superficie'].agg(
    Media='mean',       # Calcola la media
    Deviazione_Standard='std',  # Calcola la deviazione standard
    Conteggio='count'   # Calcola il conteggio
)
reg
# Out:
#                             Media  Deviazione_Standard  Conteggio
# Regione
# Abruzzo              47391.000000                  NaN          1
# Basilicata           29640.000000          8418.853188          3
# Calabria             28937.333333          5408.071221          3
# Emilia-Romagna       31149.700000         13146.748504         10
# Lazio                56260.500000         48682.994967          4
# Liguria              24029.000000                  NaN          1
# Lombardia            22700.500000            40.305087          2
# Marche               24167.666667          2633.006330          3
# Puglia               33034.736842         10047.229131         19
# Sardegna             29028.111111         10824.011738          9
# Sicilia              32548.631579          9860.175749         19
# Toscana              29941.928571          7111.643134         14
# Trentino-Alto Adige  27485.000000          3877.773588          2
# Umbria               36176.285714          9898.778270          7
# Veneto               30858.333333          9295.470635          3

# %%
comuni_superficie.groupby('Regione')['Superficie'].count()
# Out:
# Regione
# Abruzzo                 1
# Basilicata              3
# Calabria                3
# Emilia-Romagna         10
# Lazio                   4
# Liguria                 1
# Lombardia               2
# Marche                  3
# Puglia                 19
# Sardegna                9
# Sicilia                19
# Toscana                14
# Trentino-Alto Adige     2
# Umbria                  7
# Veneto                  3
# Name: Superficie, dtype: int64

# %%
comuni_superficie.groupby('Regione')['Superficie'].count().sort_values(ascending=False)
# Out:
# Regione
# Puglia                 19
# Sicilia                19
# Toscana                14
# Emilia-Romagna         10
# Sardegna                9
# Umbria                  7
# Lazio                   4
# Basilicata              3
# Marche                  3
# Veneto                  3
# Calabria                3
# Lombardia               2
# Trentino-Alto Adige     2
# Liguria                 1
# Abruzzo                 1
# Name: Superficie, dtype: int64

# %%
# !pip install jupyter-summarytools -q

# %%
from summarytools import dfSummary
dfSummary(comuni_superficie)
# Out:
# <style type="text/css">
# #T_a9489 thead>tr>th {
#   text-align: left;
# }
# #T_a9489_row0_col0, #T_a9489_row1_col0, #T_a9489_row2_col0, #T_a9489_row3_col0, #T_a9489_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_a9489_row0_col1, #T_a9489_row1_col1, #T_a9489_row2_col1, #T_a9489_row3_col1, #T_a9489_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_a9489_row0_col2, #T_a9489_row1_col2, #T_a9489_row2_col2, #T_a9489_row3_col2, #T_a9489_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_a9489_row0_col3, #T_a9489_row1_col3, #T_a9489_row2_col3, #T_a9489_row3_col3, #T_a9489_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_a9489_row0_col4, #T_a9489_row1_col4, #T_a9489_row2_col4, #T_a9489_row3_col4, #T_a9489_row4_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_a9489_row0_col5, #T_a9489_row1_col5, #T_a9489_row2_col5, #T_a9489_row3_col5, #T_a9489_row4_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_a9489">
#   <caption><strong>Data Frame Summary</strong><br>comuni_superficie<br>Dimensions: 100 x 5<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_a9489_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a9489_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_a9489_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_a9489_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_a9489_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_a9489_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a9489_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a9489_row0_col1" class="data row0 col1" ><strong>Pos.</strong><br>[int64]</td>
#       <td id="T_a9489_row0_col2" class="data row0 col2" >Mean (sd) : 50.5 (29.0)<br>min < med < max:<br>1.0 < 50.5 < 100.0<br>IQR (CV) : 49.5 (1.7)</td>
#       <td id="T_a9489_row0_col3" class="data row0 col3" >100 distinct values</td>
#       <td id="T_a9489_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_a9489_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a9489_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a9489_row1_col1" class="data row1 col1" ><strong>Comune</strong><br>[object]</td>
#       <td id="T_a9489_row1_col2" class="data row1 col2" >1. Alghero<br>2. Roma<br>3. Ravenna<br>4. Cerignola<br>5. Bagno di Romagna<br>6. San Vito<br>7. Arzachena<br>8. Reggio Emilia<br>9. Corleone<br>10. Forlì<br>11. other</td>
#       <td id="T_a9489_row1_col3" class="data row1 col3" >1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>1 (1.0%)<br>90 (90.0%)</td>
#       <td id="T_a9489_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_a9489_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a9489_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a9489_row2_col1" class="data row2 col1" ><strong>Regione</strong><br>[object]</td>
#       <td id="T_a9489_row2_col2" class="data row2 col2" >1. Puglia<br>2. Sicilia<br>3. Toscana<br>4. Emilia-Romagna<br>5. Sardegna<br>6. Umbria<br>7. Lazio<br>8. Marche<br>9. Veneto<br>10. Basilicata<br>11. other</td>
#       <td id="T_a9489_row2_col3" class="data row2 col3" >19 (19.0%)<br>19 (19.0%)<br>14 (14.0%)<br>10 (10.0%)<br>9 (9.0%)<br>7 (7.0%)<br>4 (4.0%)<br>3 (3.0%)<br>3 (3.0%)<br>3 (3.0%)<br>9 (9.0%)</td>
#       <td id="T_a9489_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_a9489_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a9489_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a9489_row3_col1" class="data row3 col1" ><strong>Provincia</strong><br>[object]</td>
#       <td id="T_a9489_row3_col2" class="data row3 col2" >1. Foggia<br>2. Grosseto<br>3. Perugia<br>4. Sassari<br>5. Caltanissetta<br>6. Catania<br>7. Taranto<br>8. Matera<br>9. Sud Sardegna<br>10. Forlì-Cesena<br>11. other</td>
#       <td id="T_a9489_row3_col3" class="data row3 col3" >9 (9.0%)<br>7 (7.0%)<br>6 (6.0%)<br>5 (5.0%)<br>4 (4.0%)<br>4 (4.0%)<br>3 (3.0%)<br>3 (3.0%)<br>3 (3.0%)<br>3 (3.0%)<br>53 (53.0%)</td>
#       <td id="T_a9489_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_a9489_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a9489_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a9489_row4_col1" class="data row4 col1" ><strong>Superficie</strong><br>[int64]</td>
#       <td id="T_a9489_row4_col2" class="data row4 col2" >Mean (sd) : 32289.0 (13560.3)<br>min < med < max:<br>22541.0 < 27842.0 < 128724.0<br>IQR (CV) : 11745.8 (2.4)</td>
#       <td id="T_a9489_row4_col3" class="data row4 col3" >99 distinct values</td>
#       <td id="T_a9489_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_a9489_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
sns.pairplot(comuni_superficie);
#https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn-pairplot

# %%
sns.pairplot(reg, height=3, aspect=1);

# %% [markdown]
# ## PETS

# %%
df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

df
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   bill   45      M  california             2         2
# 5   lisa   33      F       texas             1         2
# 6   jose   20      M       texas             4         3

# %%
df.plot(kind='scatter',x='num_children',y='num_pets',color='purple');

# %%
# gca stands for 'get current axis'
ax = plt.gca()
df.plot(kind='line',x='name',y='num_children',ax=ax)
df.plot(kind='line',x='name',y='num_pets', color='red', ax=ax);

#plt.show()

# %%
df.groupby('num_children').size().plot(kind='bar');

# %%
df.groupby('num_pets').size().plot(kind='bar');

# %%
df.groupby('state').size().plot(kind='bar');

# %%
df.groupby(['state','gender']).size().plot(kind='bar');

# %%
df.groupby(['state','gender']).size().unstack().plot(kind='bar',stacked=True);

# %%
df.groupby(['gender','state']).size().unstack().plot(kind='bar',
                                                     stacked=True,
                                                     figsize=(10, 10))
plt.legend(loc='upper left');

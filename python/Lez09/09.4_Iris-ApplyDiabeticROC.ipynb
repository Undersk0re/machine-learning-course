# %% [markdown]
# # IRIS

# %%
from IPython.display import Image
Image(url='https://frenzy86.s3.eu-west-2.amazonaws.com/fav/iris.png',width=900,height=300)
# Out:
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/fav/iris.png" width="900" height="300"/>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

dataset_path='https://frenzy86.s3.eu-west-2.amazonaws.com/fav/iris.data'

df = pd.read_csv(dataset_path, header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']
df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
df.groupby('class').count()
# Out:
#                  sepal length  sepal width  petal length  petal width
# class
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
## only notebook local
# !pip install jupyter-summarytools -q

# from summarytools import dfSummary
# dfSummary(df)

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
sns.pairplot(df, height=3, aspect=1);

# %%
sns.pairplot(df, hue='class', height=3, aspect=1);

# %%
df.hist(figsize=(12,8));

# %%
pd.plotting.scatter_matrix(df, figsize=(12,10));

# %%
df.boxplot(figsize=(20,15));

# %%
df.boxplot(by='class', figsize=(20,15));

# %%
plt.figure(figsize=(20,10));

# subplot su matrice 2x2

plt.subplot(2,2,1)
sns.violinplot(x='class', y='sepal length', data=df)
plt.subplot(2,2,2)
sns.violinplot(x='class', y='sepal width', data=df)
plt.subplot(2,2,3)
sns.violinplot(x='class', y='petal length', data=df)
plt.subplot(2,2,4)
sns.violinplot(x='class', y='petal width', data=df);

# %%
plt.figure(figsize=(16, 6))
plt.title('inserire il titolo')
plt.legend('class')
sns.countplot(x='sepal width',data=df,hue='class');

# %%
plt.figure(figsize=(10, 6))
plt.title('inserire il titolo')
sns.countplot(x='class', hue="class", data=df);

# %%
sns.jointplot(x="sepal length", y="sepal width", data=df, size=8);

# %%
sns.jointplot(x="petal length", y="petal width", data=df, size=8, color='red');

# %%
sns.lmplot(x="petal length", y="petal width",hue='class', data=df, fit_reg=False);

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x="class", y="petal length", data=df);

# %%
plt.figure(figsize=(8,10));

sns.boxplot(x="class", y="petal length", data=df);
sns.stripplot(x="class", y="petal length", data=df);

# %%
plt.figure(figsize=(13,10));

sns.violinplot(x="class", y="petal length", data=df);

# %%
#palette
plt.figure(figsize=(13,10));

sns.violinplot(x="class", y="petal length",  palette={"blue","red","yellow"}, data=df);

# %%
sns.FacetGrid(df, hue="class").map(sns.kdeplot, "petal length").add_legend();

# %%
sns.jointplot(x="sepal length", y="sepal width", data=df,ratio=10, kind='hex',color='green')

# %%
from pandas.plotting import parallel_coordinates

plt.figure(figsize=(13,10));
parallel_coordinates(df, "class",colormap='cool');

# %%
import plotly.express as px
dfx = px.data.iris()
fig = px.parallel_coordinates(dfx, color="species_id", labels={"species_id": "Species",
                "sepal_width": "Sepal Width", "sepal_length": "Sepal Length",
                "petal_width": "Petal Width", "petal_length": "Petal Length", },
                             color_continuous_scale=px.colors.diverging.Tealrose,
                             color_continuous_midpoint=2)
fig.show()

# %%
from scipy import stats

# Plot per ogni variabile
for column in df.iloc[:,0:-1].columns:
    plt.figure(figsize=(12, 4))

    # Histplot
    plt.subplot(1, 2, 1)
    sns.histplot(df[column], kde=True)

    plt.title(f'Distplot of {column}')

    # QQ-plot
    plt.subplot(1, 2, 2)
    stats.probplot(df[column], dist="norm", plot=plt)
    plt.title(f'QQ-Plot of {column}')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Noi utilizziamo il dataframe importato da UCI manualmente, ma abbiamo appena vrrificato chè è lo stesso

# %%
# store feature matrix in "x"
X = df.drop(['class'], axis=1)
# store response vector in "y"
y = df['class']

# %%
X.shape

# %%
y.shape

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression # algoritmo lineare di classificazione
from sklearn.model_selection import train_test_split

# %%
from IPython.display import Image
Image(url='https://frenzy86.s3.eu-west-2.amazonaws.com/fav/iris_8.png',width=900,height=300)

# %%
#Split the data into 70% training and 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=667
                                                    )
print(y_test)

# %%
#Train the model with Logistic Regression
model = LogisticRegression()
model.fit(X_train, y_train) #Training the model

# %%
model.intercept_ # intercette

# %%
model.coef_ # come mai 12 coeff

# %%
X_test.iloc[0] # prima riga dataset

# %%
## How classification work
## X_test.iloc[0]
X1 = 6.5 # sepal length
X2 = 3.0 # sepal width
X3 = 5.5 # petal length
X4 = 1.8 # petal width

# presi da sopra 
x1=(10.36122821-0.47684664*X1 + 0.76508588*X2 -2.3968327*X3 -0.96721658*X4) # setosa
x2=(2.10475101+0.41151869*X1 -0.18774797*X2 -0.16175093*X3 -0.84080686*X4) # versicolor
x3=(-12.46597922+0.06532795*X1 -0.57733791*X2 +2.55858363*X3 +1.80802344*X4) #  verginica

p1 = 1/(1+np.exp(-x1)) # prob setosa
p2 = 1/(1+np.exp(-x2)) # prb versicolor
p3 = 1/(1+np.exp(-x3)) #prob virginica

prob = np.array([p1,p2,p3]) # non sommano ad 1, abbiamo uno spazio di probabilità senza mutua esclusione degli eventi


# abbiamo il vincolo di mutua esclusività, lo aggiunguamo con softmax
def softmax(x):
    """Applying softmax to the array x """
    exp_x = np.exp(x - np.max(x))
    return exp_x / exp_x.sum(axis=0)

prob_normalized = softmax(prob)
prob_normalized

# per verificare la somma ad uno usiano np.sum(prob_normalized)

# %% [markdown]
# Where p1​, p2​, and p3​ are the probabilities for each class calculated using the logistic function.
#
# The probabilities are calculated using the sigmoid function (the logistic function) to map the output x values to a range between 0 and 1:
#
# $$p = \frac{1}{1 + e^{-x}}$$
# However, the probabilities you've computed might not sum up to 1 due to how you've calculated and normalized them. The probabilities of each class for a given observation should sum up to 1 after the application of the softmax function.
#
# To ensure the probabilities are correctly normalized, you should apply the softmax function to the output scores x for each class:
#
# $$\text{softmax}(x_i) = \frac{e^{x_i}}{\sum_{j=1}^{N} e^{x_j}}$$
# where N is the total number of classes.
#
# The softmax function will ensure that the probabilities sum up to 1 across all classes for a given observation. This normalization is often used in multi-class classification problems

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/python/logisticreg.png" width="800">

# %%
model.predict_proba(X_test) # si calcola quanto visto sopra, ma non a mano

# come mai vediamo questo strano array sotto, usiamo argmax

# %%
# indice 2: "virginica"
# indice 1: "versicolor"
# indice 0: "setosa"

max_prob = np.array([np.argmax(element) for element in model.predict_proba(X_test)]) # indice massimo
max_prob

# indici delle classi con prob massima

# %% [markdown]
# Il metrodo predict di LogisitiRegression(), va ad associare per ogni indice di colonna di probabilitò, la corrispondente classe:
# - indice 2: "virginica"
# - indice 1: "versicolor"
# - indice 0: "setosa"

# %%
# Il metodo predict fa tutti i passaggi precedenti in uno 
# calcola i regressori
# crea per ogni valore la probabilita
# associa alla probabilità esclusiva
# fa il passaggio `predict_proba`
# usa argmax
# associa agli indici


#Test the model
y_pred  = model.predict(X_test)
print(y_pred )# printing predictions

# %%
# print reali con i predetti

confronto = pd.DataFrame(data = [y_pred,y_test])
confronto = confronto.T
confronto.columns = ['predetti', 'reali_test']
confronto

# %%
# capiamo graficamente come testare il modello, come per i modelli lineari usiamo il test

# a differenza dei preblemi continui, con i problemi di classificazione non multi-layer l'errore non è certo 

import numpy as np
length = y_pred.shape[0] # 30
x = np.linspace(0,length,length)


plt.figure(figsize=(15,10))
plt.plot(x, y_test, label='test')
plt.plot(x, y_pred, label='predetto')
plt.legend(loc=2);


# il problema è molto semplice quidi sbaglia poco

# %%
model.predict([[2,3,5,2],[2,2,1,1]])

# %%
probs_y=model.predict_proba(X_test)
### Print results
probs_y = np.round(probs_y, 2)
res = "{:<15} | {:<15} | {:<15} | {:<15} | {:<5}".format("y_test", "y_pred", "Setosa(%)", "versicolor(%)", "virginica(%)\n")
res += "-"*65+"\n"
res += "\n".join("{:<15} | {:<15} | {:<15} | {:<15} | {:<15}".format(x, y, a, b, c) for x, y, a, b, c in zip(y_test, y_pred, probs_y[:,0], probs_y[:,1], probs_y[:,2]))
res += "\n"+"-"*65+"\n"
print(res)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test,y_pred)
print(f"L'accuracy totale è: {round(acc,2)*100}%")

# %% [markdown]
# ### save model as .PKL file

# %%
import joblib

joblib.dump(model,"logistic_reg_iris.pkl")

# %% [markdown]
# ### INFERENCE

# %%
loaded_model = joblib.load("logistic_reg_iris.pkl")
loaded_model

# %%
loaded_model.predict([[3,2,1,1]])[0]

# %% [markdown]
# # utilizzo modelli diversi

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression # il mio problema è di classificazione, il linear regression è un errore

model_lr= LogisticRegression()
model_lr.fit(X_train,y_train)
y_pred = model_lr.predict(X_test) # crea le predizioni
y_pred

from sklearn.metrics import confusion_matrix


labels = ['Iris-virginica','Iris-setosa', 'Iris-versicolor']

cm = confusion_matrix(y_test, y_pred) # y_true==y_pred
sns.heatmap(cm , square=True, annot=True, cbar=False,cmap='Blues',xticklabels=labels,yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Actual')
plt.ylabel('Prediction');

from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %%
from sklearn.ensemble import RandomForestClassifier # altro classificatore, attenzione al seed

model_rfc = RandomForestClassifier(n_estimators=100, max_depth=5)
model_rfc.fit(X_train,y_train)
y_pred = model_rfc.predict(X_test) # crea le predizioni
y_pred

from sklearn.metrics import confusion_matrix


labels = ['Iris-virginica','Iris-setosa', 'Iris-versicolor']

cm = confusion_matrix(y_test, y_pred) # y_true==y_pred
sns.heatmap(cm , square=True, annot=True, cbar=False,cmap='Blues',xticklabels=labels,yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Actual')
plt.ylabel('Prediction');

from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %% [markdown]
# # ROC

# %%
from sklearn.metrics import RocCurveDisplay # implementato nell'anno scorso

plt.figure(figsize=(8,8))
ax = plt.gca()

RocCurveDisplay.from_estimator(model_lr, X_test, y_test,ax=ax) # regression
RocCurveDisplay.from_estimator(model_rfc, X_test, y_test,ax=ax) # random forest
plt.plot([0,1],[0,1],'--b')

plt.title("Receiver Operating Characteristic (ROC) curves")
plt.legend(loc=4);
